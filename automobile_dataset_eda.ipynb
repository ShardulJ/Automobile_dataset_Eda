# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Shardul Janaskar'

# %%
os.chdir("C:/Users/Shardul Janaskar/Downloads")
import pandas as pd
df= pd.read_csv('Automobile_data.csv')

# %%
df1= df.copy()

# %%
df.shape
# Out:
# (205, 26)

# %%
import numpy as np

# %%
df.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1  convertible          rwd           front        88.6  ...            130
# 2    hatchback          rwd           front        94.5  ...            152
# 3        sedan          fwd           front        99.8  ...            109
# 4        sedan          4wd           front        99.4  ...            136
#
# ...

# %%
df.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null object
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %%
df.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %%
df['normalized-losses'].value_counts()
# Out:
# ?      41
# 161    11
# 91      8
# 150     7
# 128     6
# 104     6
# 134     6
# 103     5
# 94      5
# 95      5
# 65      5
# 168     5
# 85      5
# 74      5
# 102     5
# 93      4
# 148     4
# 106     4
# 118     4
# 122     4
# 137     3
# 154     3
# 101     3
# 83      3
# 115     3
# 125     3
# 192     2
# 119     2
# 194     2
# 113     2
# 81      2
# 164     2
# 158     2
# 108     2
# 110     2
# 145     2
# 197     2
# 87      2
# 129     2
# 188     2
# 153     2
# 89      2
# 90      1
# 121     1
# 98      1
# 142     1
# 107     1
# 186     1
# 231     1
# 256     1
# 78      1
# 77      1
# Name: normalized-losses, dtype: int64

# %%
n1  = df.loc[df['normalized-losses'] != '?']

# %%
n1 = n1['normalized-losses'].astype(str).astype(int).mean()

# %%
n1
# Out:
# 122.0

# %%
df['normalized-losses'] = df['normalized-losses'].str.replace('?',str(n1)).astype(float)

# %%
df['normalized-losses'] = df['normalized-losses'].astype(float)

# %%
df['normalized-losses'].describe()
# Out:
# count    205.000000
# mean     122.000000
# std       31.681008
# min       65.000000
# 25%      101.000000
# 50%      122.000000
# 75%      137.000000
# max      256.000000
# Name: normalized-losses, dtype: float64

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...    \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
p = df['price'].loc[df['price']!="?"]

# %%
p1 = p.median()

# %%
p1
# Out:
# 10295.0

# %%
df['price']= df['price'].str.replace('?',str(p1))

# %%
df['price']= df['price'].astype(float)

# %%
df['price']
# Out:
# 0      13495.0
# 1      16500.0
# 2      16500.0
# 3      13950.0
# 4      17450.0
# 5      15250.0
# 6      17710.0
# 7      18920.0
# 8      23875.0
# 9      10295.0
# 10     16430.0
# 11     16925.0
# 12     20970.0
# 13     21105.0
# 14     24565.0
# 15     30760.0
# 16     41315.0
# 17     36880.0
# 18      5151.0
# 19      6295.0
# 20      6575.0
# 21      5572.0
# 22      6377.0
# 23      7957.0
# 24      6229.0
# 25      6692.0
# 26      7609.0
# 27      8558.0
# 28      8921.0
# 29     12964.0
#         ...
# 175     9988.0
# 176    10898.0
# 177    11248.0
# 178    16558.0
# 179    15998.0
# 180    15690.0
# 181    15750.0
# 182     7775.0
# 183     7975.0
# 184     7995.0
# 185     8195.0
# 186     8495.0
# 187     9495.0
# 188     9995.0
# 189    11595.0
# 190     9980.0
# 191    13295.0
# 192    13845.0
# 193    12290.0
# 194    12940.0
# 195    13415.0
# 196    15985.0
# 197    16515.0
# 198    18420.0
# 199    18950.0
# 200    16845.0
# 201    19045.0
# 202    21485.0
# ...

# %%
h= df['horsepower'].loc[df['horsepower']!='?'].astype(float)

# %%
h1= h.median()

# %%
df['horsepower']= df['horsepower'].str.replace('?',str(h1))

# %%
df['horsepower']= df['horsepower'].astype(float)

# %%
pr= df['peak-rpm'].loc[df['peak-rpm']!='?'].astype(float)

# %%
pr1= pr.mean()

# %%
df['peak-rpm']= df['peak-rpm'].str.replace('?',str(pr1))

# %%
df['peak-rpm']= df['peak-rpm'].astype(float)

# %%
df
# Out:
#      symboling  normalized-losses         make fuel-type aspiration  \
# 0            3              122.0  alfa-romero       gas        std
# 1            3              122.0  alfa-romero       gas        std
# 2            1              122.0  alfa-romero       gas        std
# 3            2              164.0         audi       gas        std
# 4            2              164.0         audi       gas        std
# 5            2              122.0         audi       gas        std
# 6            1              158.0         audi       gas        std
# 7            1              122.0         audi       gas        std
# 8            1              158.0         audi       gas      turbo
# 9            0              122.0         audi       gas      turbo
# 10           2              192.0          bmw       gas        std
# 11           0              192.0          bmw       gas        std
# 12           0              188.0          bmw       gas        std
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
# symboling            205 non-null int64
# normalized-losses    205 non-null float64
# make                 205 non-null object
# fuel-type            205 non-null object
# aspiration           205 non-null object
# num-of-doors         205 non-null object
# body-style           205 non-null object
# drive-wheels         205 non-null object
# engine-location      205 non-null object
# wheel-base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb-weight          205 non-null int64
# engine-type          205 non-null object
# num-of-cylinders     205 non-null object
# engine-size          205 non-null int64
# fuel-system          205 non-null object
# bore                 205 non-null object
# stroke               205 non-null object
# ...

# %%
import seaborn as sns

# %%
df['bore'] = pd.to_numeric(df['bore'], errors = 'coerce')

# %%
df['bore'].value_counts()
# Out:
# 3.62    23
# 3.19    20
# 3.15    15
# 2.97    12
# 3.03    12
# 3.46     9
# 3.78     8
# 3.31     8
# 3.43     8
# 2.91     7
# 3.27     7
# 3.05     6
# 3.58     6
# 3.39     6
# 3.54     6
# 3.01     5
# 3.70     5
# 3.35     4
# 3.74     3
# 3.59     3
# 3.17     3
# 3.24     2
# 3.13     2
# 3.63     2
# 3.80     2
# 3.94     2
# 3.47     2
# 3.33     2
# 3.50     2
# 2.92     1
# 3.61     1
# 3.08     1
# 2.99     1
# 3.76     1
# 2.68     1
# 3.34     1
# 3.60     1
# 2.54     1
# Name: bore, dtype: int64

# %%
df['bore'].loc[df['bore'].isnull()]
# Out:
# 55   NaN
# 56   NaN
# 57   NaN
# 58   NaN
# Name: bore, dtype: float64

# %%
num = df['num-of-doors'].loc[df['num-of-doors'] != '?'].astype(str)

# %%
numb = num.mode()

# %%
df['num-of-doors']= df['num-of-doors'].str.replace('?',str(numb))

# %%
num1 = df['stroke'].loc[df['stroke'] != '?'].astype(float)

# %%
stroke = num1.mean()

# %%
df['stroke']= df['stroke'].str.replace('?',str(stroke)).astype(float)

# %%
import matplotlib.pyplot as plt

# %%
df['make'].value_counts().nlargest(5).plot(kind="bar")

# %%
df['symboling'].hist(bins = 16, color = "blue")

# %%
df['normalized-losses'].plot(kind = 'bar')

# %%
df['bore'].fillna(df['bore'].median(), inplace = True)

# %%
df['bore'].count()
# Out:
# 205

# %%
df['fuel-type'].value_counts().plot.pie(autopct = "%.2f")

# %%
df['aspiration'].value_counts().plot.pie(autopct = "%.2f")

# %%
df['drive-wheels'].value_counts().plot.pie(autopct = "%.2f")

# %%
df['horsepower'].value_counts().hist(bins = 6)
plt.title(' Horse Power Graph')
plt.ylabel('Number of vehicles')
plt.xlabel('HP')
# Out:
# Text(0.5,0,'HP')

# %%
df['num-of-doors'].value_counts().plot.bar()

# %%
corr = df.corr()

# %%
corr
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.465190   -0.531954 -0.357612
# normalized-losses   0.465190           1.000000   -0.056518  0.019209
# wheel-base         -0.531954          -0.056518    1.000000  0.874587
# length             -0.357612           0.019209    0.874587  1.000000
# width              -0.232919           0.084195    0.795144  0.841118
# height             -0.541038          -0.370706    0.589435  0.491029
# curb-weight        -0.227691           0.097785    0.776386  0.877728
# engine-size        -0.105790           0.110997    0.569329  0.683360
# bore               -0.132563          -0.030528    0.489556  0.607016
# stroke             -0.008689           0.054929    0.160944  0.129522
# compression-ratio  -0.178515          -0.114525    0.249786  0.158414
# horsepower          0.071064           0.203380    0.352876  0.553337
# ...

# %%
sns.set_context("notebook",font_scale =1.0,rc = {"lines.linewidth":2.5})
plt.figure(figsize=(13,7))
a=sns.heatmap(corr,annot = True, fmt = ".2f")

# %%
sns.lmplot('price','engine-size',df)

# %%
sns.lmplot('normalized-losses','symboling',df)

# %%
plt.scatter(df['engine-size'],df['peak-rpm'])

# %%
sns.lmplot('city-mpg','curb-weight',df,hue='make',fit_reg = False)

# %%
sns.lmplot('highway-mpg','curb-weight',df,hue='make',fit_reg = False)

# %%
plt.rcParams['figure.figsize'] = (23,10)
sns.boxplot(x= 'make', y='price',data = df)

# %%
corr = df.corr()['price']

# %%
corr
# Out:
# symboling           -0.080149
# normalized-losses    0.133823
# wheel-base           0.584847
# length               0.686567
# width                0.724558
# height               0.140439
# curb-weight          0.819817
# engine-size          0.860343
# bore                 0.532861
# stroke               0.083673
# compression-ratio    0.072890
# horsepower           0.749919
# peak-rpm            -0.106603
# city-mpg            -0.668822
# highway-mpg         -0.693037
# price                1.000000
# Name: price, dtype: float64

# %%
df.drop(['normalized-losses','height','compression-ratio','peak-rpm','length','city-mpg'],axis = 1)
# Out:
#      symboling         make fuel-type aspiration              num-of-doors  \
# 0            3  alfa-romero       gas        std                       two
# 1            3  alfa-romero       gas        std                       two
# 2            1  alfa-romero       gas        std                       two
# 3            2         audi       gas        std                      four
# 4            2         audi       gas        std                      four
# 5            2         audi       gas        std                       two
# 6            1         audi       gas        std                      four
# 7            1         audi       gas        std                      four
# 8            1         audi       gas      turbo                      four
# 9            0         audi       gas      turbo                       two
# 10           2          bmw       gas        std                       two
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.loc[df['make'] == 'jaguar']['price'].sum()
# Out:
# 103800.0
